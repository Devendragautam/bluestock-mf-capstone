# %% [markdown]
# # Advanced Analytics Insights
#
# Based on the transaction, portfolio, and NAV datasets, here are 5 advanced insights derived from the analyses:
#
# 1. **Highest Risk (VaR) Funds**: The funds with the highest VaR (most negative) are SBI Small Cap Fund - Direct Plan - Growth (-2.69%) and Axis Small Cap Fund - Regular - Growth (-2.62%).
# 2. **Most Invested Cohort**: The 2024 cohort invested the most overall (INR 3491125187), favoring UTI Nifty 50 Index Fund - Regular - Growth.
# 3. **Average SIP amount**: Usually varies around INR 0.00 across cohorts.
# 4. **SIP Continuity**: Among investors with 6+ SIPs, 0 (100.0%) are 'at-risk' (average gap > 35 days).
# 5. **Sector Concentration (HHI)**: The most concentrated equity fund is Axis Bluechip Fund - Regular - Growth with an HHI of 0.2968, indicating high sector bets.

# %% [markdown]
# ### Investor Cohort Analysis Table

# %%
import pandas as pd
# Code used to generate the above cohort analysis
cohort_df.head()
# Out:
#  Cohort Year  Avg SIP Amount (INR)  Total Invested (INR)                        Top Fund Preference
#         2024                     0            3491125187 UTI Nifty 50 Index Fund - Regular - Growth
#         2025                     0              30455243  SBI Small Cap Fund - Direct Plan - Growth
